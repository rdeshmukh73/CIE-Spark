# %%
from dotenv import load_dotenv
import os
from google import genai
from google.genai import types
import time
load_dotenv()
# Out:
# True

# %% [markdown]
# ### Grading dummy solution hypotheses

# %%
problem_solution = {
    'MMT' : {
        'problem' : """Core Problem Statement:
                        Despite the rise in online travel booking, many Indian travelers experience “post-booking
                        anxiety” — uncertainty about itinerary accuracy, hidden costs, and fragmented travel support,
                        leading to reduced trust and repeat usage.

                        Target Audience:
                        ● Primary: Indian millennials and Gen Z travelers (domestic + international trips)
                        ● Secondary: Small travel businesses and agents who rely on MMT’s platform.

                        The “Cost of the Problem”:
                        Millions of users lose time, money, and confidence when plans change or support fails. This
                        erodes loyalty and drives travelers to alternative platforms or direct bookings.""",

        'solution' : """Proposed Solution Direction:
                        A new “MMT Assured” ecosystem that combines AI-based risk prediction, verified partner
                        badges, and real-time itinerary assurance for travelers.

                        Key Value Proposition:
                        ● Before Trip: Transparent pricing, reliability score for every booking.
                        ● During Trip: Real-time support via AI assistant + instant rebooking on disruption.
                        ● After Trip: Auto-compensation for verified issues and loyalty reward points.

                        Customer Benefit:
                        Peace of mind through predictability, transparency, and proactive support — not just
                        cheaper deals."""
    },
    'Netflix' : {
        'problem' : """Core Problem Statement:
                        Movie lovers face major inconvenience in accessing the films and TV shows they want. Physical rentals are
                        often unavailable, costly, and time-consuming, while television schedules are rigid and lack viewer control.

                        Target Audience:
                        Primary: Urban youth (18–35) with regular internet access who consume movies frequently.
                        Secondary: Working professionals and families looking for convenient, affordable entertainment options.

                        The “Cost of the Problem”:
                        On average, a user spends hours commuting to and from rental stores each month, paying late fees and
                        dealing with limited stock availability — a frustrating experience for both casual and regular viewers.""",

        'solution' : """Proposed Solution Direction:
                        A digital streaming platform that allows users to instantly watch movies and TV shows online, anytime,
                        without downloads or physical media.

                        Key Value Proposition:
                        “Watch what you want, when you want.”

                        A single platform combining convenience, affordability, and personalization — revolutionizing how people
                        experience entertainment."""
    },
    'Practo' : {
        'problem' : """Core Problem Statement: The healthcare journey in India is fragmented and inefficient, creating
                    a frustrating "search-schedule-manage" loop for patients and limiting the growth potential for
                    doctors outside of major hospitals.

                    Target Audience:
                    * Primary: Patients and doctors using digital platforms for outpatient care.
                    * Secondary: Pharmacies, diagnostic centers, and insurance providers integrated into the care
                    ecosystem.

                    The "Cost of the Problem": 
                    Patients waste hours searching for the right specialist, navigating
                    unpredictable wait times, and manually tracking prescriptions. Doctors struggle with no-shows,
                    inefficient scheduling, and lack of a unified digital presence, leading to lost revenue and burnout.""",
        
        'solution' : """Proposed Solution Direction: An intelligent, integrated healthcare platform that moves beyond
                    simple booking to become a patient's health companion and a doctor's practice operating
                    system.

                    Key Value Proposition:
                    * For Patients: A single, trusted app for finding the right doctor, booking *predictable* slots,
                    managing unified health records, and seamless follow-up care (e-prescriptions, lab bookings,
                    reminders).
                    * For Doctors: A powerful SaaS tool that minimizes no-shows, optimizes scheduling,
                    automates administrative tasks, and enhances patient engagement and retention, ultimately
                    increasing practice revenue and efficiency."""
    },
    'Swiggy' : {
        'problem' : """Core Problem Statement: Inefficient last-mile delivery routing in dense urban
                    environments leads to increased operational costs, lower delivery partner earnings, and
                    inconsistent customer delivery times, particularly during peak hours.

                    Target Audience: 
                    Primary: Swiggy delivery executives and restaurant partners.
                    Secondary: End-customers experiencing variable delivery timelines.

                    The "Cost of the Problem": 
                    A 5-minute increase in delivery time per order, when
                    scaled across millions of daily orders, translates to significant losses in fuel, time, and
                    customer satisfaction, directly impacting the profitability and reliability of the service.""",

        'solution' : """Proposed Solution Direction: A machine learning-powered, predictive routing engine
                    that analyzes real-time traffic data, order density, weather patterns, and historical
                    delivery information to generate optimized, hyperlocal routes specifically for two-wheeler
                    fleets.

                    Key Value Proposition: Provides a seamless, dynamic routing system that reduces
                    delivery time and costs, thereby increasing delivery partner earnings and enhancing
                    customer satisfaction without requiring any changes to hardware or partner behavior."""
    },
    'Uber' : {
        'problem' : """Core Problem Statement:
                    Long wait times between booking and ride arrival reduce customer satisfaction, driver
                    efficiency, and platform reliability. These delays stem from inefficient demand prediction
                    and dynamic driver allocation, especially during peak hours or unpredictable traffic
                    patterns.""",
        
        'solution' : """Proposed Solution Direction:
                    An AI-powered dynamic driver allocation system using real-time traffic data, event
                    information, and demand forecasting to pre-position drivers before surges occur.

                    Key Value Proposition:
                    - Predicts high-demand zones 15–30 minutes in advance.
                    - Reduces rider wait time by 40%.
                    - Enhances driver utilization and overall system efficiency.
                    - Seamlessly integrates into Uber’s existing infrastructure."""
    },
    'Zomato' : {
        'problem' : """Core Problem Statement: High user drop-off occurs when customers switch from
                    browsing and discovery on the platform to placing an order, caused by a disconnect
                    between the dining-out experience and the food delivery service.
                    
                    Target Audience: 
                    Primary: Zomato users who browse restaurants for dining-out but
                    order from other platforms. Secondary: Restaurant partners who lose potential delivery
                    orders from customers who discovered them on Zomato for dining-in.
                    
                    The "Cost of the Problem": 
                    Significant loss of potential revenue as users discover
                    restaurants on Zomato but fulfill their delivery orders on competing platforms, effectively
                    making Zomato a discovery-only tool for a large segment of users and ceding profitable
                    transactions to rivals.""",
        
        'solution' : """Proposed Solution Direction: A context-aware "Smart Nudge" feature that, upon
                    detecting a user browsing a restaurant's dining-in profile, dynamically presents a
                    non-intrusive, compelling offer or call-to-action to order delivery from that same
                    restaurant.

                    Key Value Proposition: Creates a seamless, unified experience by intelligently
                    converting discovery intent into transactional action, increasing delivery order volume
                    and reinforcing Zomato as a one-stop solution for all food-related needs."""
    }
}

# %%
gradePrompt = '''Rate solution hypothesis given that 
- Team members : 5 undergraduate students
- Duration : 6-week hackathon, 3 hours per week per person
- Grading scale : 1-5, 1 lowest, 5 highest
- Response should include the score with a reasoning less than 100 words.
'''

client = genai.Client(api_key = os.getenv('GOOGLE_API_KEY'))

# %% [markdown]
# ### Gemini 2.5 Flash Lite

# %%
# Get Gemini 2.5 Flash Preview (~$1.4) to rate these ideas
for company in problem_solution :
    newGradePrompt = gradePrompt + \
                    'problem statement : ' + problem_solution[company]['problem'] + \
                    '\nsolution hypothesis : ' + problem_solution[company]['solution']
    
    response = client.models.generate_content(
        # model = 'gemini-2.5-flash-preview-09-2025',
        model = 'gemini-2.5-flash-lite',
        contents = newGradePrompt
    )

    print(company.upper())
    print('----------------')
    print(response)
    print()
    time.sleep(10)
# Out:
# MMT
# ----------------
# sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""Let's rate the provided solution hypothesis based on the given constraints and problem statement.
#
# **Rating the Solution Hypothesis:**
#
# I would rate this solution hypothesis a **4 out of 5**.
#
# Here's a breakdown of the reasoning:
#
# **Strengths (Why it's a strong hypothesis):**
#
# *   **Directly Addresses the Core Problem:** The "MMT Assured" ecosystem directly tackles "post-booking anxiety" by focusing on itinerary accuracy, hidden costs, and fragmented support.
# *   **Clear Value Proposition:** The key value propositions (transparent pricing, reliability score, real-time support, instant rebooking, auto-compensation, loyalty rewards) are well-defined and directly appeal to the stated pain points of travelers.
# *   **Customer Benefit is Compelling:** The emphasis on "peace of mind through predictability, transparency, and proactive support" is a strong differentiator and aligns perfectly with the problem of lost trust.
# *   **Leverages Technology:** The inclusion of "AI-based risk prediction" and "AI assistant" shows an understanding of modern technological solutions for complex problems.
# *   **Holistic Approach:** The solution spans "Before Trip," "During Trip," and "After Trip," suggesting a comprehensive approach to customer support and assurance.
# *   **Potential for Secondary Audience Benefit:** While not explicitly detailed, a more reliable platform could indirectly benefit small travel businesses by increasing customer satisfaction and reducing disputes.
# *   **Feasible for the Team/Duration (with some caveats):** The *concept* is scalable. The team can focus on developing a *prototype* or *proof-of-concept* for one or two key features within the given timeframe. For example, focusing on the AI-based risk prediction or a simplified version of the real-time itinerary assurance.
#
# **Weaknesses/Areas for Further Consideration (Why it's not a perfect 5):**
#
# *   **Complexity for a 6-Week Hackathon with Undergraduate Students:** The "MMT Assured" ecosystem sounds quite comprehensive and potentially involves significant technical backend development (AI models, integration with booking systems, real-time data feeds, payment systems for compensation).
#     *   **AI-based risk prediction:** Developing a robust AI model from scratch in 6 weeks is ambitious. They'd likely need to rely on pre-existing libraries or focus on a very specific, narrow prediction.
#     *   **Real-time itinerary assurance:** This implies deep integration with various travel providers and a sophisticated system to detect and react to changes instantly.
#     *   **Instant rebooking on disruption:** This requires partnerships and integrations with other booking platforms and potentially complex automated booking logic.
#     *   **Auto-compensation:** This involves financial systems and clear rules for what constitutes a "verified issue," which can be tricky to define and implement quickly.
# *   **Scope Management is Crucial:** The biggest risk for this team is trying to do too much. Without a very focused MVP (Minimum Viable Product) approach, they might end up with a half-baked solution across many features rather than a solid demonstration of one or two core aspects.
# *   **"Verified Partner Badges" - How?** This is a crucial element but the mechanism for "verification" isn't detailed. This could be a significant undertaking for a hackathon.
# *   **Data Requirements for AI:** The AI models would require substantial historical data to be effective. It's unlikely they'll have access to this in a hackathon setting, meaning their AI component might be more of a simulated demonstration.
#
# **Recommendations for the Team (to maximize their chances of success):**
#
# *   **Prioritize ruthlessly:** They need to decide which *one or two* aspects of "MMT Assured" are the most critical to demonstrate and focus their efforts there. Perhaps demonstrating the AI-driven risk score for a limited set of travel types or a simplified itinerary update alert system.
# *   **Focus on the "assurance" aspect:** The core value is peace of mind. They should aim to build a prototype that *feels* reassuring, even if the backend integrations are simulated.
# *   **Mockups and Prototypes:** For the more complex technical features, they can use high-fidelity mockups or prototypes to illustrate the intended functionality, rather than building the full backend.
# *   **Leverage Existing Tools/APIs:** If they can find existing, easy-to-integrate APIs for things like risk assessment (even at a conceptual level) or travel data, that would be beneficial.
#
# **In conclusion:**
#
# The solution hypothesis is strong, innovative, and directly addresses the problem. It has excellent potential. However, its ambition and the breadth of features it encompasses present a significant challenge within the given timeframe and team composition. The success will heavily depend on their ability to scope down and execute a focused prototype effectively. Therefore, a 4 is a fair rating, acknowledging the strength of the idea while recognizing the practical execution hurdles."""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash-lite' prompt_feedback=None response_id='_Ij3aNKqCd-e1e8P6LaQuAY' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=1030,
#   prompt_token_count=318,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=318
#     ),
#   ],
#   total_token_count=1348
# ) automatic_function_calling_history=[] parsed=None
#
# NETFLIX
# ----------------
# sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""Let's rate this solution hypothesis based on the provided context.
#
# Here's a breakdown of the rating:
#
# **Rating: 4/5**
#
# **Reasoning:**
#
# This is a strong solution hypothesis for the given problem statement and constraints. Here's why:
#
# **Strengths (Contributing to the High Score):**
#
# *   **Directly Addresses the Core Problem:** The problem is about inconvenience, unavailability, cost, and lack of control in accessing films and TV shows. The proposed solution directly counters these by offering instant online access, "anytime," and eliminating physical media and downloads.
# *   **Clear Value Proposition:** "Watch what you want, when you want" is a concise and powerful statement that perfectly encapsulates the core benefit and directly addresses the pain points of rigid schedules and limited availability.
# *   **Relevant Target Audience:** The primary audience (urban youth) is tech-savvy and accustomed to digital streaming. The secondary audience also benefits from the convenience and affordability.
# *   **Feasible within Constraints (with caveats):**
#     *   **Team Size:** 5 undergraduate students is a decent size for a hackathon.
#     *   **Duration:** 6 weeks, 3 hours/week/person (total ~90 hours per person, ~450 hours total). This is a good amount of time for a hackathon to build a *proof-of-concept* or a *minimum viable product (MVP)* that demonstrates the core functionality. It's unlikely they'd build a fully polished, large-scale streaming platform, but they can certainly build a compelling prototype.
# *   **"Revolutionizing Entertainment" Aspiration:** While ambitious, this aspirational goal is appropriate for a hackathon and signals a desire for significant impact.
# *   **Addresses "Cost of the Problem":** By eliminating commutes, late fees, and stock availability issues, the solution directly mitigates the financial and time costs mentioned in the problem statement.
# *   **Implicitly Addresses Affordability:** While not explicitly stated as a pricing model, a digital platform generally implies a more affordable model than per-rental or subscription models for *each* physical rental.
#
# **Areas for Minor Improvement/Consideration (Why not a perfect 5):**
#
# *   **Technical Feasibility of "Instantly Watch":** While the *concept* is clear, the technical implementation of "instantly watch" for a wide library of content can be complex. For a hackathon, this might mean focusing on a *limited* library or using readily available APIs/embedded players. The hypothesis itself doesn't detail *how* this is achieved, which is understandable for a hypothesis but could be a future point of discussion.
# *   **Content Acquisition:** The biggest hurdle for any streaming platform is content acquisition. The hypothesis assumes access to films and TV shows, which is a massive undertaking in reality. For a hackathon, this would likely involve using publicly available trailers, clips, or mock content.
# *   **Personalization Detail:** The hypothesis mentions "personalization" but doesn't elaborate. For a hackathon, this could be a stretch goal or a simpler implementation (e.g., basic recommendation engine based on watched content).
#
# **Overall:**
#
# This solution hypothesis is excellent for a hackathon setting. It's clear, directly addresses the problem, has a strong value proposition, and is reasonably aligned with the team's capacity and timeline to build a demonstrable solution. The "revolutionizing" aspect is a good motivator for a creative project. The minor points of consideration are realistic challenges of the real-world implementation, not necessarily flaws in the *hypothesis itself* within the hackathon context."""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash-lite' prompt_feedback=None response_id='C4n3aPWeCt-WosUPkfzUqQs' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=762,
#   prompt_token_count=269,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=269
#     ),
#   ],
#   total_token_count=1031
# ) automatic_function_calling_history=[] parsed=None
#
# PRACTO
# ----------------
# sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""Let's break down the solution hypothesis based on the provided context and rate it.
#
# **Analysis of the Solution Hypothesis:**
#
# *   **Alignment with Problem Statement:** The solution directly addresses the fragmented and inefficient healthcare journey.
#     *   "Single, trusted app for finding the right doctor" tackles the "search" aspect.
#     *   "Booking *predictable* slots" addresses the "unpredictable wait times" and frustration.
#     *   "Managing unified health records," "seamless follow-up care (e-prescriptions, lab bookings, reminders)" addresses the "manage" loop and manual tracking.
#     *   For doctors, "minimizes no-shows," "optimizes scheduling," "automates administrative tasks," and "enhances patient engagement and retention" directly counter the issues of no-shows, inefficient scheduling, and lack of unified digital presence.
# *   **"Intelligent" and "Integrated":** The use of these terms is good, suggesting advanced features and a holistic approach. However, *how* it's intelligent and integrated isn't detailed yet, which is expected at the hypothesis stage.
# *   **"Health Companion" and "Practice Operating System":** These are strong metaphorical descriptions that effectively communicate the envisioned depth of the platform.
# *   **Key Value Proposition:**
#     *   **For Patients:** Clearly articulated benefits like ease of finding doctors, predictable booking, unified records, and streamlined follow-up. This addresses their pain points effectively.
#     *   **For Doctors:** Clearly articulated benefits like reduced no-shows, better scheduling, automation, and revenue/efficiency gains. This also directly addresses their pain points.
# *   **"Beyond Simple Booking":** This is a crucial differentiator, indicating they understand the need for more than just a basic appointment scheduler.
#
# **Potential Areas for Deeper Exploration (Not necessarily weaknesses of the hypothesis, but next steps):**
#
# *   **"Intelligent":** What makes it intelligent? AI for doctor recommendations? Predictive analytics for appointment no-shows?
# *   **"Integrated":** How deep is the integration? With existing EMR systems? With pharmacy POS? With insurance claims?
# *   **"Unified Health Records":** This is a significant technical and regulatory challenge in India. The hypothesis assumes feasibility.
# *   **"Predictable Slots":** This implies some form of dynamic scheduling or capacity management, which is a good but potentially complex feature.
#
# **Rating the Solution Hypothesis:**
#
# Considering the stage (hypothesis) and the resources (5 undergrads, 6 weeks, 3 hours/week), this is a **strong and well-defined hypothesis.** It clearly articulates a vision that directly addresses the identified problem and its core pain points for both patients and doctors. The value proposition is compelling and differentiated.
#
# **Rating: 4.5 / 5**
#
# **Justification for the Rating:**
#
# *   **5/5:** For its excellent alignment with the problem statement, clear value proposition for both target audiences, and ambitious yet focused vision. It proposes a solution that tackles the root causes of the problem.
# *   **-0.5:** The only minor deduction is the lack of specificity on the "how" of the "intelligent" and "integrated" aspects. However, this is a natural limitation of a hypothesis stage. For a hackathon, this level of detail is more than sufficient to guide their development. The "predictable slots" and "unified health records" are ambitious but achievable within a focused scope for a hackathon project.
#
# **In summary, this is an excellent starting point for the hackathon. The team has a clear understanding of the problem and a compelling vision for its solution.**"""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash-lite' prompt_feedback=None response_id='GYn3aLXuMc6Vvr0P9IbIwAk' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=768,
#   prompt_token_count=343,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=343
#     ),
#   ],
#   total_token_count=1111
# ) automatic_function_calling_history=[] parsed=None
#
# SWIGGY
# ----------------
# sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""Let's rate the solution hypothesis based on the provided context:
#
# **Rating: 4/5**
#
# Here's a breakdown of the reasoning:
#
# **Strengths (Contributing to a high score):**
#
# *   **Directly Addresses the Core Problem:** The hypothesis directly targets the "inefficient last-mile delivery routing" by proposing a "machine learning-powered, predictive routing engine." This is a very strong alignment.
# *   **Leverages Relevant Data Sources:** The proposed solution incorporates key factors known to influence delivery times: real-time traffic, order density, weather, and historical data. This indicates a thoughtful understanding of the problem's complexities.
# *   **Focus on a Specific Fleet:** Targeting "two-wheeler fleets" is a smart specialization, as their routing needs and constraints can differ from larger vehicles. This adds realism and focus.
# *   **Clear Value Proposition:** The "Key Value Proposition" is well-articulated and directly links the solution's capabilities to the desired outcomes: reduced delivery time/costs, increased partner earnings, and enhanced customer satisfaction.
# *   **Minimal Barrier to Entry:** The statement "without requiring any changes to hardware or partner behavior" is a significant advantage. This makes adoption much more likely and easier to implement within the hackathon's constraints.
# *   **Ambitious yet Achievable for a Hackathon:** A predictive routing engine using ML is an ambitious project for a hackathon, but given the 6-week timeframe and the clear definition of the problem, it's achievable to build a functional prototype or a proof-of-concept that demonstrates the core idea.
# *   **Measurable Impact:** The "Cost of the Problem" quantifies the issue, implying that the success of the solution can be measured by reductions in delivery time and associated costs.
#
# **Areas for Potential Improvement / Considerations (Preventing a perfect 5/5):**
#
# *   **Technical Feasibility within Constraints:** While the solution is good, the *execution* of a robust ML-powered predictive routing engine within 6 weeks with 5 undergrad students (3 hours/week/person) is a significant challenge. The hypothesis doesn't explicitly mention how they will simplify or scope this for the hackathon. For a hackathon, they might need to focus on a specific aspect of the ML or a simplified data model.
# *   **Data Availability and Quality:** The hypothesis assumes access to high-quality, real-time data for traffic, order density, weather, and historical deliveries. The practicality of obtaining and integrating this data within the hackathon timeframe might be a bottleneck.
# *   **"Hyperlocal" Definition:** While a good term, the specific definition and implementation of "hyperlocal" routing within the ML model could be a point of further clarification.
# *   **Model Training and Scalability:** For a hackathon, the focus will likely be on the core routing logic. Building and training a truly predictive ML model that scales to "millions of daily orders" is beyond the scope of a hackathon project. The hypothesis implies this ultimate goal, which is good, but the immediate hackathon deliverable might be a simplified version.
#
# **In summary:**
#
# The solution hypothesis is strong, well-aligned with the problem, and offers a clear value proposition with minimal adoption barriers. It's a compelling direction for a hackathon. The only reason it's not a perfect 5/5 is the inherent challenge of fully realizing such a sophisticated ML system within the specified hackathon constraints. The team will need to carefully scope their MVP to make it achievable."""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash-lite' prompt_feedback=None response_id='KIn3aMSlE66Gvr0Pu4mw-AQ' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=743,
#   prompt_token_count=285,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=285
#     ),
#   ],
#   total_token_count=1028
# ) automatic_function_calling_history=[] parsed=None
#
# UBER
# ----------------
# sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""Let's break down the rating of this solution hypothesis based on the provided context.
#
# ## Rating the Solution Hypothesis
#
# **Overall Rating: 4/5**
#
# Here's a breakdown of why:
#
# **Strengths:**
#
# *   **Directly Addresses the Core Problem:** The solution hypothesis clearly links back to the problem statement. It aims to solve "long wait times" by tackling "inefficient demand prediction and dynamic driver allocation."
# *   **Leverages Relevant Technologies:** The use of "AI-powered," "real-time traffic data," "event information," and "demand forecasting" are all appropriate and modern approaches to this kind of problem.
# *   **Quantifiable Value Proposition:** The claims of "Predicts high-demand zones 15–30 minutes in advance" and "Reduces rider wait time by 40%" are specific and measurable. This is crucial for demonstrating impact.
# *   **Clear Benefits:** The other value propositions ("Enhances driver utilization," "overall system efficiency," "Seamlessly integrates") are also strong and address key business objectives.
# *   **Feasible Scope (with caveats):** The *concept* of an AI-powered dynamic driver allocation system is sound. The feasibility of *implementation* within the hackathon constraints is where the caveats lie.
#
# **Weaknesses/Areas for Consideration (and why it's not a perfect 5):**
#
# *   **Ambition vs. Hackathon Constraints:** The most significant challenge is the scope of the proposed solution against the team's resources.
#     *   **Team Size:** 5 undergraduate students is a decent size, but for a complex AI system, it can still be limiting.
#     *   **Duration:** 6 weeks at 3 hours/week/person is a *very* limited amount of time (total of 90 person-hours). Building a robust AI model, integrating with real-time data sources, and developing a functional allocation system from scratch within this timeframe is highly ambitious.
#     *   **Complexity of "AI-powered dynamic driver allocation":** This involves multiple components:
#         *   **Data Collection & Preprocessing:** Gathering and cleaning real-time traffic, event, and historical demand data.
#         *   **Demand Forecasting Model:** Developing and training an AI model (e.g., time-series forecasting, machine learning models).
#         *   **Dynamic Allocation Algorithm:** Designing an algorithm that uses predictions to instruct drivers.
#         *   **Integration Layer:** Creating an interface to interact with existing systems (even if conceptual).
# *   **"Seamlessly integrates into Uber’s existing infrastructure":** This is a very bold claim for a hackathon project. While the *goal* is integration, a hackathon project would likely be a proof-of-concept demonstrating the *logic* of integration, not a fully functional integration.
# *   **Underlying Data Availability & Quality:** The hypothesis assumes access to high-quality, real-time data for traffic, events, and historical demand. For a hackathon, this might be simulated data, which could limit the realism of the solution.
#
# **Reasoning for the 4/5 Rating:**
#
# The solution hypothesis is strong *conceptually* and *strategically*. It clearly identifies the problem and proposes a well-aligned, innovative solution with clear benefits. However, the inherent difficulty of building such a system, especially within the severe time constraints of a hackathon, introduces a significant risk of not fully realizing the proposed value proposition in its entirety.
#
# A perfect 5 would require the hypothesis to be either:
#
# 1.  **More focused and scoped down:** For example, a proof-of-concept focusing *only* on the demand prediction model for a specific area, or a simplified allocation algorithm.
# 2.  **Acknowledging the limitations:** Acknowledging that a hackathon might only deliver a *prototype* or a *demonstration* of the core AI logic, rather than a fully integrated system.
#
# Despite these challenges, the *direction* is excellent, and the team has clearly thought about the problem and its potential solutions. They've set a high bar, which is commendable for a hackathon. The rating reflects the strength of the *idea* and its alignment with the problem, tempered by the practical realities of execution within the given constraints."""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash-lite' prompt_feedback=None response_id='N4n3aKy-JpCG1e8P-uC66Q0' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=898,
#   prompt_token_count=211,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=211
#     ),
#   ],
#   total_token_count=1109
# ) automatic_function_calling_history=[] parsed=None
#
# ZOMATO
# ----------------
# sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""Let's break down the solution hypothesis and rate it based on the provided context.
#
# ## Rating the Solution Hypothesis:
#
# Here's a breakdown and a rating for the proposed solution hypothesis:
#
# **1. Understanding of the Problem:**
#
# *   **Strengths:** The hypothesis directly addresses the core problem statement: user drop-off between browsing for dining and ordering delivery. It clearly identifies the disconnect between the dining-out experience and delivery service. The "Cost of the Problem" section highlights the revenue loss, which is a strong motivator.
# *   **Weaknesses:** While it understands the *symptom* (drop-off), it could be more nuanced about the *root causes* of the disconnect. Is it price? Convenience? Lack of immediate delivery options? The hypothesis assumes the primary driver is a lack of awareness of delivery options for that *specific* restaurant.
#
# **2. Clarity and Specificity of the Solution:**
#
# *   **Strengths:** The "Smart Nudge" feature is conceptually clear. The idea of a "context-aware" and "dynamic" presentation of offers is a good starting point.
# *   **Weaknesses:**
#     *   **"Smart Nudge" is vague:** What *kind* of nudges? What triggers them specifically? Is it just browsing the menu, or looking at opening hours?
#     *   **"Non-intrusive, compelling offer/call-to-action":** This is the *most* critical part, and it's the least defined. What makes it compelling? A discount? Free delivery? Faster delivery promise? A personalized recommendation? Without defining the nature of the "offer," it's hard to assess its potential effectiveness.
#     *   **"Dynamically presents":** How is this dynamic? Is it based on time of day, location, user's past behavior, or restaurant's current delivery capacity?
#
# **3. Feasibility within Constraints (Team, Duration):**
#
# *   **Strengths:** The core concept of a "nudge" is not overly technically complex. It likely involves front-end UI/UX work and some backend logic for triggering. This is generally achievable within a hackathon setting.
# *   **Weaknesses:**
#     *   **"Context-aware" and "dynamic" can quickly become complex:** If "context-aware" means sophisticated user behavior analysis, machine learning, or real-time restaurant inventory integration, then 6 weeks for 5 undergrads might be tight.
#     *   **Developing compelling offers:** This requires user research and potentially A/B testing to find what's truly compelling, which is beyond the scope of a hackathon. The team will have to *assume* what's compelling.
#     *   **Integration:** Depending on Zomato's existing architecture, integrating a new feature might require significant backend work.
#
# **4. Innovation and Impact:**
#
# *   **Strengths:** The idea of bridging the dining-out discovery and delivery ordering gap is innovative. It aims to create a more holistic user experience and increase Zomato's transactional revenue, which is a significant potential impact.
# *   **Weaknesses:** The "smart nudge" concept itself isn't entirely novel. Many platforms use similar push notifications or in-app prompts. The innovation lies in *how effectively* Zomato implements this for the specific dining-out to delivery transition. The *compelling offer* is the key to differentiating this.
#
# **5. Alignment with Target Audience:**
#
# *   **Strengths:** It directly targets Zomato users who browse for dining but order elsewhere. The secondary benefit to restaurants is also acknowledged.
# *   **Weaknesses:** The hypothesis assumes that *all* these users are willing to switch for a nudge. Some might have genuine reasons (e.g., delivery cost is too high, preferred delivery platform offers better rewards).
#
# **Overall Rating:**
#
# **3.5 / 5**
#
# **Justification for the Rating:**
#
# The solution hypothesis is **good** because it:
#
# *   **Directly addresses a critical problem:** The revenue loss due to users discovering on Zomato but ordering elsewhere is a clear pain point.
# *   **Proposes a logical solution direction:** A "smart nudge" to bridge the gap is intuitive.
# *   **Has a clear value proposition:** Creating a unified experience and increasing transactions is a strong outcome.
#
# However, it's not a perfect 5 for the following reasons:
#
# *   **Lack of specific detail on "compelling offers":** This is the Achilles' heel. Without defining what makes an offer compelling, the hypothesis remains somewhat abstract. The success of the "nudge" hinges entirely on this.
# *   **Potential for underestimation of complexity:** While the core idea is feasible, the "context-aware" and "dynamic" aspects, if implemented deeply, could stretch the team's resources and time.
# *   **Assumptive nature of the "nudge":** It assumes a nudge is the primary missing element, without deep validation of *why* users are dropping off.
#
# **Recommendations for Improvement (within the hackathon scope):**
#
# *   **Prioritize defining 1-2 *specific* types of compelling offers.** For example:
#     *   "A limited-time discount (e.g., 10% off) on delivery for the first 30 minutes after browsing."
#     *   "Free delivery on orders placed within the next hour."
#     *   "A small complimentary item from the restaurant for delivery orders placed this evening."
# *   **Define clear triggers for the nudge.** What specific user actions on a restaurant's dining profile will initiate the nudge?
# *   **Outline a simple mechanism for the nudge.** Will it be a pop-up? A banner? A persistent button?
# *   **Acknowledge the need for future iteration.** The team can state that initial nudges might be basic, and future development would involve learning from user interactions to refine the offers and triggers.
#
# This refined hypothesis would be stronger, more actionable, and better positioned to demonstrate tangible results within the hackathon."""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash-lite' prompt_feedback=None response_id='SIn3aN6AHeqa1e8P96O7sQU' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=1283,
#   prompt_token_count=332,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=332
#     ),
#   ],
#   total_token_count=1615
# ) automatic_function_calling_history=[] parsed=None

# %% [markdown]
# ### Ratings from Flash-lite
# MMT : 4/5 <br>
# Netflix : 4/5 <br>
# Practo : 4.5/5 <br>
# Swiggy : 4/5 <br>
# Uber : 4/5 <br>
# Zomato : 3.5/5 <br>

# %% [markdown]
# ### Gemini 2.5 Flash Preview

# %%
# Get Gemini 2.5 Flash Preview (~$1.4) to rate these ideas
for company in problem_solution :
    newGradePrompt = gradePrompt + \
                    'problem statement : ' + problem_solution[company]['problem'] + \
                    '\nsolution hypothesis : ' + problem_solution[company]['solution']
    
    response = client.models.generate_content(
        model = 'gemini-2.5-flash-preview-09-2025',
        contents = newGradePrompt
    )

    print(company.upper())
    print('----------------')
    print(response)
    print()
    time.sleep(10)
# Out:
# ---------------------------------------------------------------------------
# ServerError                               Traceback (most recent call last)
# Cell In[7], line 7
#       2 for company in problem_solution :
#       3     newGradePrompt = gradePrompt + \
#       4                     'problem statement : ' + problem_solution[company]['problem'] + \
#       5                     '\nsolution hypothesis : ' + problem_solution[company]['solution']
# ----> 7     response = client.models.generate_content(
#       8         model = 'gemini-2.5-flash-preview-09-2025',
#       9         contents = newGradePrompt
#      10     )
#      12     print(company.upper())
#      13     print('----------------')
#
# File ~/Desktop/CIESpark/CIEVenv/lib/python3.12/site-packages/google/genai/models.py:4983, in Models.generate_content(self, model, contents, config)
#    4981 while remaining_remote_calls_afc > 0:
#    4982   i += 1
# -> 4983   response = self._generate_content(
#    4984       model=model, contents=contents, config=parsed_config
#    4985   )
#    4987   function_map = _extra_utils.get_function_map(parsed_config)
#    4988   if not function_map:
#
# File ~/Desktop/CIESpark/CIEVenv/lib/python3.12/site-packages/google/genai/models.py:3795, in Models._generate_content(self, model, contents, config)
#    3792 request_dict = _common.convert_to_dict(request_dict)
#    3793 request_dict = _common.encode_unserializable_types(request_dict)
# -> 3795 response = self._api_client.request(
#    3796     'post', path, request_dict, http_options
#    3797 )
#    3799 if config is not None and getattr(
#    3800     config, 'should_return_http_response', None
#    3801 ):
#    3802   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File ~/Desktop/CIESpark/CIEVenv/lib/python3.12/site-packages/google/genai/_api_client.py:1292, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1282 def request(
#    1283     self,
#    1284     http_method: str,
#    (...)   1287     http_options: Optional[HttpOptionsOrDict] = None,
#    1288 ) -> SdkHttpResponse:
#    1289   http_request = self._build_request(
#    1290       http_method, path, request_dict, http_options
#    1291   )
# -> 1292   response = self._request(http_request, http_options, stream=False)
#    1293   response_body = (
#    1294       response.response_stream[0] if response.response_stream else ''
#    1295   )
#    1296   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~/Desktop/CIESpark/CIEVenv/lib/python3.12/site-packages/google/genai/_api_client.py:1128, in BaseApiClient._request(self, http_request, http_options, stream)
#    1125     retry = tenacity.Retrying(**retry_kwargs)
#    1126     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1128 return self._retry(self._request_once, http_request, stream)
#
# File ~/Desktop/CIESpark/CIEVenv/lib/python3.12/site-packages/tenacity/__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File ~/Desktop/CIESpark/CIEVenv/lib/python3.12/site-packages/tenacity/__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~/Desktop/CIESpark/CIEVenv/lib/python3.12/site-packages/tenacity/__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     418 retry_exc = self.retry_error_cls(fut)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File ~/Desktop/CIESpark/CIEVenv/lib/python3.12/site-packages/tenacity/__init__.py:187, in RetryError.reraise(self)
#     185 def reraise(self) -> t.NoReturn:
#     186     if self.last_attempt.failed:
# --> 187         raise self.last_attempt.result()
#     188     raise self
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/Desktop/CIESpark/CIEVenv/lib/python3.12/site-packages/tenacity/__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/Desktop/CIESpark/CIEVenv/lib/python3.12/site-packages/google/genai/_api_client.py:1105, in BaseApiClient._request_once(self, http_request, stream)
#    1097 else:
#    1098   response = self._httpx_client.request(
#    1099       method=http_request.method,
#    1100       url=http_request.url,
#    (...)   1103       timeout=http_request.timeout,
#    1104   )
# -> 1105   errors.APIError.raise_for_response(response)
#    1106   return HttpResponse(
#    1107       response.headers, response if stream else [response.text]
#    1108   )
#
# File ~/Desktop/CIESpark/CIEVenv/lib/python3.12/site-packages/google/genai/errors.py:110, in APIError.raise_for_response(cls, response)
#     108   raise ClientError(status_code, response_json, response)
#     109 elif 500 <= status_code < 600:
# --> 110   raise ServerError(status_code, response_json, response)
#     111 else:
#     112   raise cls(status_code, response_json, response)
#
# ServerError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
